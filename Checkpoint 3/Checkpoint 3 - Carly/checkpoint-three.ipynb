# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/bbhatt001/human-microbiome-project
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd

hmp_df = pd.read_csv("../project_catalog (1)-Copy1.csv")
hmp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2915 entries, 0 to 2914
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   HMP ID                   2915 non-null   int64
#  1   GOLD ID                  1783 non-null   object
#  2   Organism Name            2915 non-null   object
#  3   Domain                   2712 non-null   object
#  4   NCBI Superkingdom        2751 non-null   object
#  5   HMP Isolation Body Site  2915 non-null   object
#  6   Project Status           2915 non-null   object
#  7   Current Finishing Level  1579 non-null   object
#  8   NCBI Submission Status   2915 non-null   object
#  9   NCBI Project ID          2915 non-null   int64
#  10  Genbank ID               1579 non-null   object
#  11  Gene Count               2915 non-null   int64
#  12  IMG/HMP ID               2915 non-null   int64
#  13  HOMD ID                  397 non-null    object
#  14  Sequencing Center        2911 non-null   object
#  15  Funding Source           2915 non-null   object
#  16  Strain Repository ID     1377 non-null   object
# dtypes: int64(4), object(13)
# memory usage: 387.3+ KB

# %%
hmp_df.shape
# Out:
# (2915, 17)

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
hmp_df.isnull()
# Out:
#       HMP ID  GOLD ID  Organism Name  Domain  NCBI Superkingdom  \
# 0      False    False          False   False              False
# 1      False    False          False   False              False
# 2      False    False          False   False              False
# 3      False    False          False   False              False
# 4      False    False          False   False              False
# ...      ...      ...            ...     ...                ...
# 2910   False    False          False   False              False
# 2911   False    False          False   False              False
# 2912   False    False          False   False              False
# 2913   False    False          False   False              False
# 2914   False    False          False   False              False
#
#       HMP Isolation Body Site  Project Status  Current Finishing Level  \
# 0                       False           False                    False
# 1                       False           False                    False
# 2                       False           False                    False
# 3                       False           False                    False
# 4                       False           False                    False
# ...                       ...             ...                      ...
# 2910                    False           False                    False
# 2911                    False           False                    False
# 2912                    False           False                    False
# 2913                    False           False                    False
# 2914                    False           False                    False
#
#       NCBI Submission Status  NCBI Project ID  Genbank ID  Gene Count  \
# 0                      False            False       False       False
# 1                      False            False       False       False
# 2                      False            False       False       False
# 3                      False            False       False       False
# 4                      False            False       False       False
# ...                      ...              ...         ...         ...
# 2910                   False            False       False       False
# 2911                   False            False       False       False
# 2912                   False            False       False       False
# 2913                   False            False       False       False
# 2914                   False            False       False       False
#
#       IMG/HMP ID  HOMD ID  Sequencing Center  Funding Source  \
# 0          False    False              False           False
# 1          False     True              False           False
# 2          False    False              False           False
# 3          False    False              False           False
# 4          False     True              False           False
# ...          ...      ...                ...             ...
# 2910       False     True              False           False
# 2911       False     True              False           False
# 2912       False     True              False           False
# 2913       False     True              False           False
# 2914       False     True              False           False
#
#       Strain Repository ID
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 2910                 False
# 2911                 False
# 2912                 False
# 2913                 False
# 2914                 False
#
# [2915 rows x 17 columns]

# %% [markdown]
# The results of the .isnull() check reveal only null values present in the HOMD ID column. Looking into the datasource lets me know that this column is an ID from [the human oral microbiome database](http://www.homd.org/index.php?name=HOMD&view=dynamic&oraltaxonid=389).
# I don't plan on using this ID to tackle the business issue, so I'll delete the column altogether.

# %%
hmp_df = hmp_df.drop('HOMD ID', axis = 1)
hmp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2915 entries, 0 to 2914
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   HMP ID                   2915 non-null   int64
#  1   GOLD ID                  1783 non-null   object
#  2   Organism Name            2915 non-null   object
#  3   Domain                   2712 non-null   object
#  4   NCBI Superkingdom        2751 non-null   object
#  5   HMP Isolation Body Site  2915 non-null   object
#  6   Project Status           2915 non-null   object
#  7   Current Finishing Level  1579 non-null   object
#  8   NCBI Submission Status   2915 non-null   object
#  9   NCBI Project ID          2915 non-null   int64
#  10  Genbank ID               1579 non-null   object
#  11  Gene Count               2915 non-null   int64
#  12  IMG/HMP ID               2915 non-null   int64
#  13  Sequencing Center        2911 non-null   object
#  14  Funding Source           2915 non-null   object
#  15  Strain Repository ID     1377 non-null   object
# dtypes: int64(4), object(12)
# memory usage: 364.5+ KB

# %% [markdown]
# The output above shows me that the HOMD ID column was dropped. The output only contains a summary of the rows, however. I should find the sum of the null values present in the whole dataframe to be sure that there are not other null values in other columns not showing up in the summary above.

# %%
hmp_df.isnull().sum()
# Out:
# HMP ID                        0
# GOLD ID                    1132
# Organism Name                 0
# Domain                      203
# NCBI Superkingdom           164
# HMP Isolation Body Site       0
# Project Status                0
# Current Finishing Level    1336
# NCBI Submission Status        0
# NCBI Project ID               0
# Genbank ID                 1336
# Gene Count                    0
# IMG/HMP ID                    0
# Sequencing Center             4
# Funding Source                0
# Strain Repository ID       1538
# dtype: int64

# %% [markdown]
# Indeed there are several other columns containing null values. These are: GOLD ID, Domain, NCBI Superkingdom, Current Finishing level, Genbank ID, and Strain Repository ID.
# From this list, the only columns I remain interested in exploring are Domain and NCBI Superkingdom,. The rest I do not need in my analysis. I'll drop them.

# %%
hmp_df = hmp_df.drop(['GOLD ID', 'Current Finishing Level', 'Genbank ID', 'Strain Repository ID'], axis = 1)

# %%
hmp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2915 entries, 0 to 2914
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   HMP ID                   2915 non-null   int64
#  1   Organism Name            2915 non-null   object
#  2   Domain                   2712 non-null   object
#  3   NCBI Superkingdom        2751 non-null   object
#  4   HMP Isolation Body Site  2915 non-null   object
#  5   Project Status           2915 non-null   object
#  6   NCBI Submission Status   2915 non-null   object
#  7   NCBI Project ID          2915 non-null   int64
#  8   Gene Count               2915 non-null   int64
#  9   IMG/HMP ID               2915 non-null   int64
#  10  Sequencing Center        2911 non-null   object
#  11  Funding Source           2915 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 273.4+ KB

# %%
hmp_df.isnull().sum()
# Out:
# HMP ID                       0
# Organism Name                0
# Domain                     203
# NCBI Superkingdom          164
# HMP Isolation Body Site      0
# Project Status               0
# NCBI Submission Status       0
# NCBI Project ID              0
# Gene Count                   0
# IMG/HMP ID                   0
# Sequencing Center            4
# Funding Source               0
# dtype: int64

# %%
hmp_df['Domain']=hmp_df['Domain'].fillna(value='NO DOMAIN')
hmp_df['NCBI Superkingdom']=hmp_df['NCBI Superkingdom'].fillna(value='NO KINGDOM')
hmp_df.isnull().sum()
# Out:
# HMP ID                     0
# Organism Name              0
# Domain                     0
# NCBI Superkingdom          0
# HMP Isolation Body Site    0
# Project Status             0
# NCBI Submission Status     0
# NCBI Project ID            0
# Gene Count                 0
# IMG/HMP ID                 0
# Sequencing Center          4
# Funding Source             0
# dtype: int64

# %% [markdown]
# After filling in the null domain and superkingdom elements, I see that i missed another column with a few null values: 'Sequencing Center'. I dont expect to need this information for the project either so I'll remove it.

# %%
hmp_df=hmp_df.drop('Sequencing Center', axis=1)
hmp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2915 entries, 0 to 2914
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   HMP ID                   2915 non-null   int64
#  1   Organism Name            2915 non-null   object
#  2   Domain                   2915 non-null   object
#  3   NCBI Superkingdom        2915 non-null   object
#  4   HMP Isolation Body Site  2915 non-null   object
#  5   Project Status           2915 non-null   object
#  6   NCBI Submission Status   2915 non-null   object
#  7   NCBI Project ID          2915 non-null   int64
#  8   Gene Count               2915 non-null   int64
#  9   IMG/HMP ID               2915 non-null   int64
#  10  Funding Source           2915 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 250.6+ KB

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
hmp_df.describe()
# Out:
#             HMP ID  NCBI Project ID   Gene Count    IMG/HMP ID
# count  2915.000000      2915.000000  2915.000000  2.915000e+03
# mean   3193.047684    152890.012007  1474.622642  2.250715e+08
# std    3055.524395    104857.664414  1653.762393  5.295180e+08
# min       1.000000         0.000000     0.000000  0.000000e+00
# 25%    1262.500000     49365.000000     0.000000  0.000000e+00
# 50%    2122.000000    169465.000000  1517.000000  0.000000e+00
# 75%    3096.500000    269820.500000  2489.500000  0.000000e+00
# max    9999.000000    311149.000000  8490.000000  2.524023e+09

# %% [markdown]
# The only numerical column that would have outliers is Gene Count. The others are IDs. I know from my EDA workbook (checkpoint 2) what the distribution of Gene Count looks like. I dont not wish to remove any outliers at this time.

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %% [markdown]
# I've removed several columns that contained null values that I know I am not interested in exploring further from the perspective of my business issue. Most of these were alternative identifier figures from other databases for the organisms studied. I probably will also not be interested in doing any analysis with submission status, project project status, or funding source. However, I'll keep them for now in case they prove to be interesting figures to work with in Tableau.

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
hmp_df.head(50)
# Out:
#     HMP ID                                Organism Name     Domain  \
# 0        1             Abiotrophia defectiva ATCC 49176  BACTERIAL
# 1        4          Achromobacter piechaudii ATCC 43553  BACTERIAL
# 2        5               Achromobacter xylosoxidans C54  BACTERIAL
# 3       10           Acinetobacter baumannii ATCC 19606  BACTERIAL
# 4       12          Acinetobacter calcoaceticus RUH2202  BACTERIAL
# 5       13                      Acinetobacter sp. SH024  BACTERIAL
# 6       14                    Acinetobacter sp. RUH2624  BACTERIAL
# 7       15        Acinetobacter haemolyticus ATCC 19194  BACTERIAL
# 8       16                Acinetobacter johnsonii SH046  BACTERIAL
# 9       17                  Acinetobacter lwoffii SH145  BACTERIAL
# 10      18           Acinetobacter radioresistens SH164  BACTERIAL
# 11      19            Acinetobacter radioresistens SK82  BACTERIAL
# 12      20              Acinetobacter baumannii 6013113  BACTERIAL
# 13      21              Acinetobacter baumannii 6013150  BACTERIAL
# 14      22              Acinetobacter baumannii 6014059  BACTERIAL
# 15      23                 Acinetobacter sp. ATCC 27244  BACTERIAL
# 16      26                    Acinetobacter junii SH205  BACTERIAL
# 17      27              Actinobacillus ureae ATCC 25976  BACTERIAL
# 18      43        Actinobaculum P1 oral taxon 183 F0552  BACTERIAL
# 19      44             Actinomyces coleocanis DSM 15436  BACTERIAL
# 20      45                 Actinomyces graevenitzii C83  BACTERIAL
# 21      50         Actinomyces odontolyticus ATCC 17982  BACTERIAL
# 22      51               Actinomyces odontolyticus C702  BACTERIAL
# 23      58           Actinomyces urogenitalis DSM 15434  BACTERIAL
# 24      59                    Actinomyces viscosus C505  BACTERIAL
# 25      61               Aerococcus viridans ATCC 11563  BACTERIAL
# 26      63              Aeromicrobium marinum DSM 15272  BACTERIAL
# 27      67        Anaerovorax sp. ORNL_6EZ5-Gt_3_Pl1-27  BACTERIAL
# 28      68                     Alistipes sp. 10_1_37FAA  BACTERIAL
# 29      69               Alistipes putredinis DSM 17216  BACTERIAL
# 30      70       Anaerovorax sp. ORNL_6EZ5-Gt_3_Pl2-127  BACTERIAL
# 31      71           Anaerococcus hydrogenalis DSM 7454  BACTERIAL
# 32      72         Anaerococcus lactolyticus ATCC 51172  BACTERIAL
# 33      76                     Anaerococcus sp. S9 PR-5  BACTERIAL
# 34      77            Anaerococcus tetradius ATCC 35098  BACTERIAL
# 35      78            Anaerococcus vaginalis ATCC 51170  BACTERIAL
# 36      79       Anaerofustis stercorihominis DSM 17244  BACTERIAL
# 37      80                 Anaeroglobus geminatus F0357  BACTERIAL
# 38      81                Anaerostipes caccae DSM 14662  BACTERIAL
# 39      82          Anaerotruncus colihominis DSM 17241  BACTERIAL
# 40      83  Aneurinibacillus aneurinilyticus ATCC 12856  BACTERIAL
# 41      86                   Atopobium rimae ATCC 49626  BACTERIAL
# 42      91                  Atopobium vaginae DSM 15829  BACTERIAL
# 43     101                       Bacteroides sp. 2_1_16  BACTERIAL
# 44     102                       Bacteroides sp. 2_1_22  BACTERIAL
# 45     104                       Bacteroides sp. 3_1_19  BACTERIAL
# 46     107      Bacteroidales bacterium ORNL_2OR_SD_356  BACTERIAL
# 47     108     Bacteroidetes bacterium ORNL_1UT_ORNL_28  BACTERIAL
# 48     109                Bacteroides caccae ATCC 43185  BACTERIAL
# 49     110            Bacteroides capillosus ATCC 29799  BACTERIAL
#
#    NCBI Superkingdom HMP Isolation Body Site Project Status  \
# 0           Bacteria                    oral       Complete
# 1           Bacteria                 airways       Complete
# 2           Bacteria                 airways       Complete
# 3           Bacteria        urogenital_tract       Complete
# 4           Bacteria                    skin       Complete
# 5           Bacteria                    skin       Complete
# 6           Bacteria                    skin       Complete
# 7           Bacteria                 airways       Complete
# 8           Bacteria                    skin       Complete
# 9           Bacteria                    skin       Complete
# 10          Bacteria  gastrointestinal_tract       Complete
# 11          Bacteria                    skin       Complete
# 12          Bacteria                    skin       Complete
# 13          Bacteria                    skin       Complete
# 14          Bacteria                    skin       Complete
# 15          Bacteria                    skin       Complete
# 16          Bacteria  gastrointestinal_tract       Complete
# 17          Bacteria                 airways       Complete
# 18        NO KINGDOM                    oral       Complete
# 19          Bacteria        urogenital_tract       Complete
# 20          Bacteria                 airways       Complete
# 21          Bacteria                    oral       Complete
# 22          Bacteria                 airways    In Progress
# 23          Bacteria        urogenital_tract       Complete
# 24          Bacteria                 airways       Complete
# 25          Bacteria        urogenital_tract       Complete
# 26          Bacteria                    oral       Complete
# 27          Bacteria                 unknown    In Progress
# 28          Bacteria  gastrointestinal_tract    In Progress
# 29          Bacteria  gastrointestinal_tract       Complete
# 30          Bacteria                 unknown    In Progress
# 31          Bacteria  gastrointestinal_tract       Complete
# 32          Bacteria        urogenital_tract       Complete
# 33          Bacteria        urogenital_tract    In Progress
# 34          Bacteria        urogenital_tract       Complete
# 35          Bacteria                    skin       Complete
# 36          Bacteria  gastrointestinal_tract       Complete
# 37          Bacteria                    oral       Complete
# 38          Bacteria  gastrointestinal_tract       Complete
# 39          Bacteria  gastrointestinal_tract       Complete
# 40          Bacteria  gastrointestinal_tract       Complete
# 41          Bacteria                    oral       Complete
# 42          Bacteria        urogenital_tract       Complete
# 43          Bacteria  gastrointestinal_tract       Complete
# 44          Bacteria  gastrointestinal_tract       Complete
# 45          Bacteria  gastrointestinal_tract       Complete
# 46          Bacteria                 unknown    In Progress
# 47          Bacteria                 unknown    In Progress
# 48          Bacteria  gastrointestinal_tract       Complete
# 49          Bacteria  gastrointestinal_tract       Complete
#
#                               NCBI Submission Status  NCBI Project ID  \
# 0   6. annotation (and sequence) public on NCBI site            33011
# 1   6. annotation (and sequence) public on NCBI site            46343
# 2   6. annotation (and sequence) public on NCBI site            38739
# 3   6. annotation (and sequence) public on NCBI site            38509
# 4   6. annotation (and sequence) public on NCBI site            38337
# 5   6. annotation (and sequence) public on NCBI site            41947
# 6   6. annotation (and sequence) public on NCBI site            38511
# 7   6. annotation (and sequence) public on NCBI site            43187
# 8   6. annotation (and sequence) public on NCBI site            38339
# 9   6. annotation (and sequence) public on NCBI site            38343
# 10  6. annotation (and sequence) public on NCBI site            38345
# 11  6. annotation (and sequence) public on NCBI site            34081
# 12  6. annotation (and sequence) public on NCBI site            33017
# 13  6. annotation (and sequence) public on NCBI site            33071
# 14  6. annotation (and sequence) public on NCBI site            33073
# 15  6. annotation (and sequence) public on NCBI site            30949
# 16  6. annotation (and sequence) public on NCBI site            38341
# 17  6. annotation (and sequence) public on NCBI site            52977
# 18  6. annotation (and sequence) public on NCBI site           173932
# 19  6. annotation (and sequence) public on NCBI site            31427
# 20  6. annotation (and sequence) public on NCBI site            38761
# 21  6. annotation (and sequence) public on NCBI site            18171
# 22                   4. sequence public on NCBI site            38741
# 23  6. annotation (and sequence) public on NCBI site            31429
# 24  6. annotation (and sequence) public on NCBI site            38743
# 25  6. annotation (and sequence) public on NCBI site            38729
# 26  6. annotation (and sequence) public on NCBI site            34545
# 27                    2. project has NCBI project id           217536
# 28                   4. sequence public on NCBI site            41949
# 29  6. annotation (and sequence) public on NCBI site            19655
# 30                    2. project has NCBI project id           217537
# 31  6. annotation (and sequence) public on NCBI site            30747
# 32  6. annotation (and sequence) public on NCBI site            30951
# 33                   4. sequence public on NCBI site           219648
# 34  6. annotation (and sequence) public on NCBI site            31433
# 35  6. annotation (and sequence) public on NCBI site            38727
# 36  6. annotation (and sequence) public on NCBI site            19657
# 37  6. annotation (and sequence) public on NCBI site            50397
# 38  6. annotation (and sequence) public on NCBI site            18213
# 39  6. annotation (and sequence) public on NCBI site            19659
# 40  6. annotation (and sequence) public on NCBI site            38313
# 41  6. annotation (and sequence) public on NCBI site            30999
# 42  6. annotation (and sequence) public on NCBI site            31435
# 43  6. annotation (and sequence) public on NCBI site            38347
# 44  6. annotation (and sequence) public on NCBI site            38349
# 45  6. annotation (and sequence) public on NCBI site            41951
# 46                    2. project has NCBI project id           217538
# 47                    2. project has NCBI project id           217539
# 48  6. annotation (and sequence) public on NCBI site            18163
# 49  6. annotation (and sequence) public on NCBI site            18173
#
#     Gene Count  IMG/HMP ID                Funding Source
# 0         1950   643886181  NIH-HMP Jumpstart Supplement
# 1         5755   647000200  NIH-HMP Jumpstart Supplement
# 2         6010           0  NIH-HMP Jumpstart Supplement
# 3         3832   647533101  NIH-HMP Jumpstart Supplement
# 4         3632   646206267  NIH-HMP Jumpstart Supplement
# 5         3703   647533108  NIH-HMP Jumpstart Supplement
# 6         3693   647533107  NIH-HMP Jumpstart Supplement
# 7         3491   647000202  NIH-HMP Jumpstart Supplement
# 8         3434   646206268  NIH-HMP Jumpstart Supplement
# 9         3202   646206270  NIH-HMP Jumpstart Supplement
# 10        2938   646206271  NIH-HMP Jumpstart Supplement
# 11        3188   645058758  NIH-HMP Jumpstart Supplement
# 12        4010   647000203                     NIH-NHGRI
# 13        3964   647000204                     NIH-NHGRI
# 14        3880   647000205                     NIH-NHGRI
# 15        3327   643886214                     NIH-NHGRI
# 16        3252   646206269  NIH-HMP Jumpstart Supplement
# 17        2475   649989900  NIH-HMP Jumpstart Supplement
# 18        2320           0     NIH-HMP Sequencing Center
# 19        1546   643886017  NIH-HMP Jumpstart Supplement
# 20        1853  2513237375  NIH-HMP Jumpstart Supplement
# 21        2159   640963058                 NIH-HMP NHGRI
# 22           0           0  NIH-HMP Jumpstart Supplement
# 23        2403   643886015  NIH-HMP Jumpstart Supplement
# 24        2587   649989905  NIH-HMP Jumpstart Supplement
# 25        1929   647000207  NIH-HMP Jumpstart Supplement
# 26        3081   645951844  NIH-HMP Jumpstart Supplement
# 27           0           0     NIH-HMP Sequencing Center
# 28           0           0                     NIH-NHGRI
# 29        2742   641736205                 NIH-HMP NHGRI
# 30           0           0     NIH-HMP Sequencing Center
# 31        2069   642979323                 NIH-HMP NHGRI
# 32        2253   643886145                     NIH-NHGRI
# 33           0           0                       NIH-HMP
# 34        2079   643886055  NIH-HMP Jumpstart Supplement
# 35        1764   645058761  NIH-HMP Jumpstart Supplement
# 36        2331   641736193                 NIH-HMP NHGRI
# 37        2148  2513237300     NIH-HMP Sequencing Center
# 38        3748   641736227                 NIH-HMP NHGRI
# 39        4427   641736271                 NIH-HMP NHGRI
# 40        6214           0  NIH-HMP Jumpstart Supplement
# 41        1548   643886019  NIH-HMP Jumpstart Supplement
# 42        1244   643886063  NIH-HMP Jumpstart Supplement
# 43        4683   647533110                     NIH-NHGRI
# 44        4814   647533111                     NIH-NHGRI
# 45        4328   648861002                     NIH-NHGRI
# 46           0           0     NIH-HMP Sequencing Center
# 47           0           0     NIH-HMP Sequencing Center
# 48        3855   640963023                 NIH-HMP NHGRI
# 49        4833   640963014                 NIH-HMP NHGRI

# %% [markdown]
# From a look at the first 50 entries, the only inconsistency I see is some entries with a gene count of 0. This may cause some issues later while visualizing, but I have no need to remove those entries right now.

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# 2. Did the process of cleaning your data give you new insights into your dataset?
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?

# %% [markdown]
# 1. Yes, in some columns there were missing and irregular figures.
# 2. Yes, I am more familiar with the few entities I'm actually interested in explorin
